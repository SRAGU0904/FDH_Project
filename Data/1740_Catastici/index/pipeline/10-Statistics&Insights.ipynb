# %%
import pandas as pd
import plotly.express as px
from collections import Counter

# Add the parent directory of the 'utils' directory to the Python path
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
import utils.utils as u

# %% [markdown]
# ### Expand dataset for multiple owners

# %% [markdown]
# #### Load dataset

# %%
df = pd.read_json('../data_catastici/data_post-processing/pipeline_steps/catastici_1741_STD.json')
df['uidx'] = df['uidx'].astype(str)
df.head()
# Out:
#   uidx  id                                         owner_name   owner_code  \
# 0    0   1  Liberal Campi secondo prete titolato della Chiesa          PPL
# 1    1   2    Filippo Frari terzo prete titolato della Chiesa          PPL
# 2    2   3                              Pievan di San Cancian  ent_REL_TTL
# 3    3   4    Filippo Frari terzo prete titolato della Chiesa          PPL
# 4    4   5                         Agostin Filippi di Vicenza          PPL
#
#   owner_count owner_count_remark           owner_entity  \
# 0           1
# 1           1
# 2           1                     PIEVAN DI SAN CANCIAN
# 3           1
# 4           1
#
#        owner_entity_group owner_first_name owner_family_name  ... id_napo  \
# 0                                  Liberal             CAMPI  ...    3052
# 1                                  Filippo             FRARI  ...    3051
# 2  CHIESA DI SAN CANCIANO                                     ...     nan
# 3                                  Filippo             FRARI  ...     nan
# 4                                  Agostin           FILIPPI  ...     nan
#
#   quantity_income quality_income  author                     place  \
# 0             nan            nan  Davide  Campo vicino alla Chiesa
# 1             nan            nan  Davide  Campo vicino alla Chiesa
# 2             nan            nan  Davide  Campo vicino alla Chiesa
# 3             nan            nan  Davide  Campo vicino alla Chiesa
# 4             nan            nan  Davide  Campo vicino alla Chiesa
#
#         parish sestiere       uid  \
# 0  San Cancian       CN  CNC-0001
# 1  San Cancian       CN  CNC-0002
# 2  San Cancian       CN  CNC-0003
# 3  San Cancian       CN  CNC-0004
# 4  San Cancian       CN  CNC-0005
#
#                                       path_img  \
# 0  436_Cannaregio/11_SCancian/SCancian_0_1.png
# 1  436_Cannaregio/11_SCancian/SCancian_0_1.png
# 2  436_Cannaregio/11_SCancian/SCancian_0_1.png
# 3  436_Cannaregio/11_SCancian/SCancian_0_1.png
# 4  436_Cannaregio/11_SCancian/SCancian_0_1.png
#
#                                       geometry
# 0  POINT (291832.8461721611 5035321.328300701)
# 1  POINT (291841.5307544547 5035307.748867494)
# 2  POINT (291845.4782538932 5035313.512255858)
# 3  POINT (291846.4256626792 5035312.091152506)
# 4   POINT (291824.082739216 5035303.564443278)
#
# [5 rows x 28 columns]

# %% [markdown]
# #### Load necessary dictionaries

# %%
first_names = sorted(pd.read_json('../dictionaries/PPL_dictionary/first_names.json')[0].to_list(), key=len, reverse=True)
unknown_relatives_plur = sorted(pd.read_json('../dictionaries/PPL_dictionary/unknown_relatives_plur.json')[0].to_list(), key=len, reverse=True)

# %% [markdown]
# #### Expand dataset - one row per owner

# %%
owner_count_index = df.columns.get_loc("owner_count")
df.insert(owner_count_index, "parcel_portion", 1)

# %%
def expand_rows(row, columns_with_pipe):
    expanded_rows = []
    
    reference_col = 'owner_family_group' if len(row['owner_family_group']) > 0 else 'owner_entity_group'
    num_owners = row[reference_col].count('|') + 1
    
    for i in range(num_owners):
        new_row = row.copy()
        
        for col in columns_with_pipe:
            split_values = row[col].split('|')
            if " | " in row[col] and len(split_values) < num_owners:
                split_values += ['-'] * (num_owners - len(row[col].split('|')))
            
            if i < len(split_values):
                new_row[col] = u.remove_extra_spaces(split_values[i])
        
        # assign new uid
        new_row['uidx'] = f"{new_row['uidx']}_{i}"
        
        # assign parcel portion
        new_row['parcel_portion'] = round(1.0 / num_owners, 2)
        
        # adjust title
        if len(new_row.get('owner_title_std', '')) > 0 and new_row.get('owner_title', '') == '-':
            new_row['owner_title'] = new_row.get('owner_title_std', '')
        
        # adjust owner count
        if new_row.get('owner_first_name', '').replace('_', '') in unknown_relatives_plur:
            new_row['owner_count'] = 2
            new_row['owner_count_remark'] = '2+'
        else:
            new_row['owner_count'] = 1
            new_row['owner_count_remark'] = ''
            
        expanded_rows.append(new_row)
        
    return expanded_rows

# %%
df_filtered = df[df.apply(lambda x: (isinstance(x['owner_family_group'], str) and len(x['owner_family_group']) > 0 and '|' in x['owner_family_group']) or 
                                      (isinstance(x['owner_entity_group'], str) and len(x['owner_entity_group']) > 0 and '|' in x['owner_entity_group']), axis=1)]


columns_with_pipe = [col for col in df_filtered.columns if df_filtered[col].astype(str).str.contains(' | ', regex=False).any()]

expanded_parcels = []
df_filtered.apply(lambda row: expanded_parcels.extend(expand_rows(row, columns_with_pipe)), axis=1)
df_expanded = pd.DataFrame(expanded_parcels)

# %%
df['uidx'] = df['uidx'].astype(str)

new_rows_list = []
for index, row in df.iterrows():
    original_uidx = row['uidx']
    matching_expanded_rows = df_expanded[df_expanded['uidx'].str.startswith(original_uidx + "_")]
    
    if not matching_expanded_rows.empty:
        new_rows_list.extend(matching_expanded_rows.to_dict('records'))
    else:
        new_rows_list.append(row.to_dict())

df_expanded_merged = pd.DataFrame(new_rows_list)
df_expanded_merged['uidx'] = df_expanded_merged['uidx'].astype(str)

# %%
df_expanded_merged.to_json('../data_catastici/data_post-processing/pipeline_steps/catastici_1741_STD_expanded.json', orient='records')

# %%
with pd.ExcelWriter('../data_catastici/data_post-processing/catastici_1741_STD_expanded.xlsx') as writer:
    df_expanded_merged.to_excel(writer, sheet_name='catastici_1741')

# %% [markdown]
# ### Distribution of Owner Count

# %%
owner_count_counts = df['owner_count'].value_counts().reset_index()
owner_count_counts.columns = ['owner_count', 'count']

fig = px.bar(owner_count_counts, x='owner_count', y='count', title='Distribution of Owner Counts')
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.update_traces(texttemplate='%{y}', textposition='inside')
fig.show()

# %% [markdown]
# ### Distribution of Owner Codes

# %% [markdown]
# #### Not assigned or to-verify entries

# %%
filtered_df = df[df['owner_code'].str.contains('VRF') | (df['owner_code'] == 'TODO')].copy()

owner_code_counts = filtered_df['owner_code'].value_counts().reset_index()
owner_code_counts.columns = ['owner_code', 'count']

fig = px.bar(owner_code_counts, x='owner_code', y='count', title='Distribution of unassigned or to-verify entries')
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.update_traces(texttemplate='%{y}', textposition='inside')
fig.show()

# %% [markdown]
# #### The following entries have to be verified by hand

# %%
filtered_df = df[df['owner_code'].str.contains('VRF') | (df['owner_code'] == 'TODO')].copy()
filtered_df.loc[:, 'owner_name'] = filtered_df['owner_name'].apply(lambda x: u.text_to_minimal(x))
unique_owner_names = filtered_df['owner_name'].unique()

for i, owner_name in enumerate(unique_owner_names):
    print(i+1, ": ", owner_name)
# Out:
# 1 :  francesco maria segalla da vicenza
# 2 :  demetrio conte
# 3 :  giovanni battista e lodovico calice q. bortolo
# 4 :  santa sporini relicta quondam giacomo marchi
# 5 :  bernardi alessio ruini
# 6 :  nobil homo gerolamo lion cavazza
# 7 :  conte bertoli
# 8 :  luganeghera in barbaria delle tavole
# 9 :  luganeghera in barbaria dalle tavole
# 10 :  nobil homo conte zuanne vidiman
# 11 :  conte antonio e fratello bortoli
# 12 :  signor conte antonio bartoli
# 13 :  nobili homini conti cesare e nipoti piovene
# 14 :  nobili homini ser antonio zorzi, conte lodovico manin, ser piero girolamo capello
# 15 :  illustrissima signora anna maria marcello piceni
# 16 :  nobil homo ser conte zuanne vidiman
# 17 :  nobil homo ser girolamo michiel lini
# 18 :  nobil homo ser marco michiel salamon
# 19 :  nobil homo ser conte lodovico manin
# 20 :  ill.mo conte francesco gerardini
# 21 :  antonio maria giani bernardini
# 22 :  nobil donna fiorenza lion marcello
# 23 :  conte girolamo benzon
# 24 :  conte ferro da padova
# 25 :  conte cucina padovano
# 26 :  conte cucina da padova
# 27 :  illustrissimo stae
# 28 :  conte giuseppe pianese
# 29 :  abate cruci
# 30 :  nobil homini gerolamo diedo di iseppo e iseppo diedo di gasparo
# 31 :  nobil homo alvise contarini procuratore eredi paolina contarini
# 32 :  nobil homo agostino correggio q. pietro
# 33 :  reverendo don felice maria sandei monaco in san giorgio maggiore
# 34 :  conte angelo bartoli
# 35 :  conte antonio bartoli
# 36 :  nobil domina antonia giustinian lipomano
# 37 :  nobil homo ser alvise priuli de ser alessandro
# 38 :  santa musitelli
# 39 :  conte michiel angelo e fratello cornioni da padova
# 40 :  conte francesco santolini
# 41 :  nobil homo ser zorzi contarini cavalier conte dal zaffo
# 42 :  domino steffano e ferdinando conti vigonza
# 43 :  domino iseppo e ferdinando conti fratelli vigonza
# 44 :  domino steffano e ferdinando conti fratelli vigonza
# 45 :  conte marcantonio trento
# 46 :  giovanni venantio santa maria
# 47 :  domino andrea marin contarini
# 48 :  andrea marin contarini
# 49 :  anzola, pietro, giulia, domenica e giustina prezatto all'orto
# 50 :  anzola, pietro, giulia, domenica, giustina prezato all'orto
# 51 :  nobil homo magno santa ternita
# 52 :  fabia cavalieri
# 53 :  antonio conte bartoli
# 54 :  domini iseppo, francesco zanchi quondam giovanni pietro per uso, et nicolo con fratelli quondam gerolamo per uso
# 55 :  nobil homo ser giacomo corner come commissario del fu ser daniel morosini quondam andrea
# 56 :  conte antonio fratelli bertoli
# 57 :  conte piceni
# 58 :  conte piceni pietro
# 59 :  conte vittorio picceni
# 60 :  ka renier santa margherita
# 61 :  conte antonio bertoli
# 62 :  conte bartoli
# 63 :  secondo prete in san marcola per uso, casa del titolo
# 64 :  nobili homeni fratelli diedo santa fosca
# 65 :  nobili homeni fratelli conti govannelli fu de ser conte carlo vicenzo
# 66 :  era del fu ser vettor grimani ora del nobil homo ser michiel grimani fu de ser zuanne carlo
# 67 :  nobil homo sagredo santa ternita
# 68 :  nobili homini conti pioveni
# 69 :  nobil homo conte zenobio
# 70 :  nobil homo girolamo michiel lin
# 71 :  maria santa sorelle lanza ercole
# 72 :  maria santa sorelle lanza e ercole
# 73 :  maria santa sorelle lanza
# 74 :  nobil homini gerolamo lorenzo antonio fratelli giustinian
# 75 :  nobil homo giovanni conte widman
# 76 :  nobil homo conte giovanni widman
# 77 :  nobil homo tomaso morosini schiavina
# 78 :  annibale mazariol da sacil
# 79 :  conte gerolamo mieso da padova
# 80 :  conte girolamo miera da padova
# 81 :  bortolo zanchi q. paolo
# 82 :  nobil donna elena michiel zane
# 83 :  nobil homo giovanni conte vidman fu de lodovico
# 84 :  nobil homo giovanni conte vidman
# 85 :  illustrissimo signor conte giulio santorini
# 86 :  illustrissimo abate trevisan
# 87 :  nobil homo ser vicenzo da riva sessionario del nobil homo ser lorenzo semitecolo
# 88 :  nobil domina alba giustinian procuratoressa cornero, francesco giustinian grimani et maria giustinian contarini eredi del quondam nobi homo ser antonio giustinian fu loro padre
# 89 :  nobil domina alba giustinian corner relicta del nobil homo ...procurator corner ca grande
# 90 :  nobil domina alba giustinian corner
# 91 :  nobil homo ser michiel marin contarini
# 92 :  conte vicenzo brianti
# 93 :  nobil homo ser polo michiel morosini in san cancian
# 94 :  nobil homo ser polo michiel morosini
# 95 :  illustrissimo signori conte giulio e conte francesco santolini
# 96 :  illustrissimo signro conte santolini
# 97 :  illustrissimo signor conte santolini
# 98 :  nobil homo ser conte giovanni vidman
# 99 :  nobil domina alba giustinian corner procuratoressa
# 100 :  nobil homo ser lodovico conte vidiman
# 101 :  nobil homo ser zuanne conte vidman
# 102 :  nobil homo ser conte zuanne vidman fu di ser lodovico che fu di ser giovanni paulo
# 103 :  francesco calvi q. zuanne
# 104 :  giovanni nattista traversi
# 105 :  marco e lucio e marin quondam zuanne fratelli riva, riscuotono e sorelle riva monache alle vergini per uso livello
# 106 :  francesco, sgualdo, antonio, giulia e suor marina e suor angela fratelli e sorelle suboldi
# 107 :  silvestro monaco
# 108 :  gerolamo michiel lin
# 109 :  fabia cavalieri tutrice de propri figli
# 110 :  giovanni donato correggio
# 111 :  zan tomaso soranzo
# 112 :  elena maccarini, angelica castagna, maddalena regoni, anzola bioni, antonio zini, antonio poli, isabetta stainer
# 113 :  marco michiel salamon
# 114 :  maria di zorzi chindeler
# 115 :  francesco fini fu di vicenzo procurator di san marco
# 116 :  piero correr fu di zuanne uxorio nomine
# 117 :  cattarina zorzi magno
# 118 :  conte pera da verona
# 119 :  conte gioppi pisanese
# 120 :  sargente maggior giacomo galuzzi
# 121 :  maria michiel moretta monaca sant'andrea
# 122 :  elena maria paulucci monaca san gerolamo
# 123 :  elena maria paulucci moncasa san gerolamo
# 124 :  conte antonio lando
# 125 :  conte giulio santonini
# 126 :  conte antonio e fratello bartoli
# 127 :  teresa nicoli monaca santa maria del oration di malamoco
# 128 :  nicolo conti
# 129 :  michiel conti
# 130 :  conte stefano vigonza
# 131 :  gerolamo gianeli per giacomo forti
# 132 :  conte benedetto corbelli di padova
# 133 :  conte benedetto corbelli
# 134 :  conte benetto corbelli
# 135 :  nobil donna giustiniana cornera, francesca giustinian grimani, maria giustina contarini
# 136 :  nobil donna maria raspi monaca san iseppo
# 137 :  conte benetto corbeli padova
# 138 :  conte benetto corbelli padova
# 139 :  francesco zon segretario
# 140 :  maria aurora todarini monaca in san giuseppe
# 141 :  todero memo s. margherita
# 142 :  todero memo s. margarita
# 143 :  giovanni michiel giansich
# 144 :  nobil homo abate camillo trevisan
# 145 :  suor michiela moretti monacha santa luccia
# 146 :  sanson conte martinengo
# 147 :  conte nicolo giustinian di verona
# 148 :  pietro soranzo de marco
# 149 :  conte giulio santonini da padova
# 150 :  conte giovanelli
# 151 :  maggior nicolo craina
# 152 :  ferigo marcello riva di biasio
# 153 :  marc'antonio giustinian molin
# 154 :  francesco giovanni agostin fratelli campelli
# 155 :  domenico contarini de fantin
# 156 :  vincenzo contarini de fantin
# 157 :  giambattista grassi q. lorenzo
# 158 :  lorenzo e margarita fratelli dal bon q. pietro
# 159 :  giambattista grarro q. lorenzo
# 160 :  nadal dona de lorenzo
# 161 :  pietro lazari q. mattio
# 162 :  giovanni giupponi q. pietro
# 163 :  antonio cavagni q. carlo
# 164 :  noobil homo antonio cavagnis q. carlo
# 165 :  agostin coreggio q. piero
# 166 :  zanetta lucatelli lasciata per testamento da bianca trevisan fu de fransco r. scipion boldu
# 167 :  zuanne dona de bortolo
# 168 :  margarita filippini lasciata per testamento da bianca trevisan fu de francesco r. scipion boldu
# 169 :  cristofolo ed alessandro orsetti q. salvador
# 170 :  nobil homo marco pisani de paolo uxorio nomine
# 171 :  nobil homo mattio vitturi de lorenzo
# 172 :  nobili homini polo contarini, giacomo bembo, marc'antonio tiepolo, alvise da mosto e altri
# 173 :  cornelia cavalli rel. q. sebastian steffani
# 174 :  cornelia cavalli rel. q. sebastian stefani
# 175 :  elisabetta majeo dell'illustrissimo abbate giovanni francesco vezzamano
# 176 :  lucietta contarini rel. q. dionisio rossi
# 177 :  nobil homo marco pisani de paolo
# 178 :  giacomina piceni q. gianmaria
# 179 :  zuanne cabrini q. antonio
# 180 :  nobil donna agnese pasqualigo rel. nicolo morosini
# 181 :  conte bertoldo cesare valvason
# 182 :  conte maria ferri
# 183 :  reverenda suor maria rosalia burnata monacha al sepolcro
# 184 :  francesco giustinian orsatto
# 185 :  figlie della quondam anzola monaco
# 186 :  antonia giustinian lipomano
# 187 :  conte diodato sceriman
# 188 :  conte antonio maria bonacossi uxorio nomine di eugenia bozza
# 189 :  conte lodovico vidiman
# 190 :  polo michiel morosini
# 191 :  piero de franceschi q. bartolo
# 192 :  piero de franceschi q. bortolo
# 193 :  nobil homo lodovico giustinian de vescovi
# 194 :  nobil homo zuanne dolfin de vicenzo
# 195 :  cavalieri gritti di santa maria zobenigo
# 196 :  nobil homo marc'antonio michiel de zuanne
# 197 :  nobil donna alba giustinian corner
# 198 :  nobil homo piero sagredo q. zuanne
# 199 :  nobil donna alba giustinian cornaro
# 200 :  nobil donna alba giustinian cornero
# 201 :  francesco cavagnis q. giacomo
# 202 :  nobil donna alba giustinian procuratia corner
# 203 :  nobil homo marc'antonio michiel de domenico
# 204 :  nobil homini conti collalti
# 205 :  illustrissimo antonio marin bellini e altri
# 206 :  nobil homo antonio molin q. francesco
# 207 :  francesco rizzo giusto
# 208 :  zuanne pellegrini q. giulian e fratelli
# 209 :  domina maria eccelsa celsi monacha in san cosmo della giudecca
# 210 :  nobil homo lodovico giustinian de francesco
# 211 :  nobil homo piero giustinian q. francesco
# 212 :  andrea pietra santa
# 213 :  bontio santa caterina
# 214 :  valentin zuliani de paolo
# 215 :  eredi del conte ogniben
# 216 :  zan giorgio scotti
# 217 :  nobil homo abate grimani
# 218 :  francesco domestici nomine conte scoti
# 219 :  nobil homo ser conte francesco barbaran fu de ser carlo
# 220 :  nobil homo ser giacomo canal de messer antonio procurator
# 221 :  marco e anzolo fratelli gritti et alvise et anzolo fratelli e germani respective gritti
# 222 :  illustrissima signora maria alvisa balbi monacha professa in santa marta
# 223 :  conte pietro borisi da capo d'istria
# 224 :  illustrissima domina maria alvisa balbi monacha in santa marta
# 225 :  nobil homo ser marc'antonio mocenigo de ser zuanne
# 226 :  nobil homo ser conte nicolo manin
# 227 :  nobil homo conte nicolo manin
# 228 :  giovanni zorzi scotti
# 229 :  eredi del quondam conte giovanni paolo bonomo
# 230 :  battista conti
# 231 :  giovanni battita agazzi
# 232 :  nobil homo ser pietro maria contarina dal bovolo
# 233 :  illustrissimi conti bartoli
# 234 :  nobil homo ser lodovico giustinian de vescovi
# 235 :  nobil homo filippo abate dona
# 236 :  angiola babo san barnaba calle longa
# 237 :  angiolo grapin santa margherita
# 238 :  nobil domina luchese loredana ruzzini
# 239 :  nobil homo ser zorzi cavalier conte del zaffo
# 240 :  nobil domina giulia conte giovanelli
# 241 :  la meta de zuanne barbarigo de gerolemo, l'altra meta de marc'antonio barbarigo
# 242 :  conti fratelli ludovico e bernardo paresani abitanti in roma
# 243 :  nobil domina isabetta michiel badoer
# 244 :  conti giovanni paulo e fratelli cremona
# 245 :  girolamo cavalieri da comacchio, martin mazzarol, zuanne banetti, francesco sanson, cattarina sanson a padoa, cattarina agazzi relicta di antonio sanson, come tutrice di florian suo figlio
# 246 :  soranza e pelegrin ferandi fratelli, marietta, iseppo e mattio grillo fratelli treviso, zanetta melati treviso, marieta relicta antonio melati come tutrice di alessandro melati suo figlio
# 247 :  nobil homo polo michiel morosini
# 248 :  nobili homini ser zorzi, et fratelli manolesso e consorti, cioe li detti nobili homini per caratti 6, et l'illustrissimo signor iseppo olivieri per caratti 18
# 249 :  nobil domina elisabetta malipiero gritti et francesco vendramin da sant'alvise
# 250 :  nobil domina beatrice balbi, bianca balbi, bianca barbaro, stefano balbi, paolina balbi, daniel balbi; fu di ser lucio, cecilia pasqualigo, stefano pasqualigo tutti consorti
# 251 :  nobil domina beatrice balbi, bianca balbi, bianca barbaro, stefano balbi, paolina balbi, daniel balbi; fu di ser lucio, cecilia pasqualigo, stefano pasqualigo, francesco elia tutti consorti
# 252 :  nobil domina alba giustinian cornaro procuratoressa
# 253 :  nobil homo ser conte antonio valmarana
# 254 :  nobil homo ser benetto contarini consorti ser anibale ferari
# 255 :  nobili homini ser conte gerolemo, et fratelli zenobii
# 256 :  nobil homo ser nicolo venier fu di ser sebastian uxorio nomine
# 257 :  nobil homo ser piero grimani de ser marco antonio
# 258 :  nobil homo ser piero grimani de ser marco antonio uxorio nomine
# 259 :  nobil homo ser nicolo venier fu de ser sebastiano uxorio nomine
# 260 :  cattarina querini relicta del quondam giacinto pocobelli al presente consorte di pietro antonuti
# 261 :  alba giustinian procuratoressa corner come procuratrice delli nobili homini suoi figli
# 262 :  allegra r. sanson grassini
# 263 :  samuel q. aron coen e moise aron
# 264 :  anna consorte abram q. moise malta
# 265 :  enrico spilimbergo, olin vitta saraval
# 266 :  fiorenza lion cavazza r. anzolo marcello
# 267 :  simon q. iseppo vitta todesco
# 268 :  sara q. aron comis
# 269 :  isach q. salamon todesco
# 270 :  madalena consorte piero antonio deodati
# 271 :  giacob q. sanson grasini
# 272 :  tersia r. salamon levi
# 273 :  piu cosorti cioe ca lin, ca gradenigo, maggia, romanin e isach levi
# 274 :  anselmo q. david coen e nipoti
# 275 :  anselmo q. david cividal gemelli
# 276 :  giacomo erz olia moise naso
# 277 :  anselmo gentili q. leon
# 278 :  bonaventura treves r. marco todesco
# 279 :  bonaventura r. marco todesco
# 280 :  isach q. lion bardolan
# 281 :  isach q. lion bortolani
# 282 :  isach q. lion bortolan
# 283 :  anselmo q. lion gentili
# 284 :  david q. rafael vita bono
# 285 :  samule di michiel corsi
# 286 :  alberto astori q. giovanni maria
# 287 :  anselmo q. david cividal tevel
# 288 :  abram parenzo de moise
# 289 :  abram paranzo de moise
# 290 :  michiel e marin, zio e nipote, contarini
# 291 :  sarra sages r. david manis
# 292 :  abram aron mazerata
# 293 :  zuanne capello de bortolamio
# 294 :  ricca canis r. vita sacchi
# 295 :  giusta albegnacan q. samuel
# 296 :  enrica albegnacan q. abram
# 297 :  moise david todesco
# 298 :  iosef samuel levi da fiorenza
# 299 :  perla consorte david isdrael
# 300 :  moise q. salamon valentin
# 301 :  rachael q. david abalanza
# 302 :  nobil homo antonio corresini del q. piero
# 303 :  nobil homo giovanni marin pesero
# 304 :  nobil donna luchese loredana priuli
# 305 :  nobil homo pietro abate canal
# 306 :  nobil dona maria ciuran labia
# 307 :  nobil donna chiara dieda religiosa professa san alvise
# 308 :  faustina querini bragadina
# 309 :  nobil donna faustina querini bragadina
# 310 :  nobil homo zuanne conte vidman
# 311 :  nobil homini conti fratelli giovanelli
# 312 :  nobil homini conti zenobio
# 313 :  anna e antonia e lodovico fratello e sorelle pipari e francesco giazzi
# 314 :  zan pietro zucca
# 315 :  nobil dona giulia bonlin
# 316 :  zan francesco viti
# 317 :  nobil homo andrea polo renier
# 318 :  zan pietro zuca
# 319 :  nobil homo zan antonio baglioni
# 320 :  francesco conti
# 321 :  nobil homo marco molin fu di filippo da san fantin
# 322 :  francesco conti da cesana
# 323 :  francesco abate chiluzzi
# 324 :  nobil homo zan alvise mosto
# 325 :  antonio conte schetti
# 326 :  santa zugno
# 327 :  francesco barbaro s. chiara
# 328 :  conte vergineo curti
# 329 :  conti giovan e francesco verginei
# 330 :  coco, erizzo, contarini, bembo,
# 331 :  conte antonio suarez
# 332 :  orazio rolla q. francesco
# 333 :  abate gerolamo malanotti
# 334 :  illustrissimo ser angelo lipomano figlio del nobil homo ser zuanne battista
# 335 :  nobil homo conte zuanne vidman
# 336 :  illustrissimo signor conte giuseppe pianese di udine
# 337 :  nobili homini ser francesco zen, ser vettor antonio alvise marcello, rocco sanfermo
# 338 :  nobil homo conte iseppo e fratelli giovanelli
# 339 :  santa cattarina callogera relicta bortolo sanzonio
# 340 :  nobil homo ser conte zuanne vidman fu de ser lodovico
# 341 :  nobil homo ser pietro antonio dolfin fu de ser antonio uxorio nomine
# 342 :  nobil homo ser nicolo dona fu de ser francesco uxorio nomine
# 343 :  nobil homo ser marc'antonio mocenigo fu de ser zuanne uxorio nomine
# 344 :  anzolo giustinian orsato
# 345 :  zuanne michiel priuli
# 346 :  agostin correggio pietro
# 347 :  conte cesare e nipoti piovene
# 348 :  vincenzo canal q. emilio, girolamo nadal, vincenzo canal q. girolamo
# 349 :  antonio grimani de giovanni battista
# 350 :  vicenzo molin da s. cattarina
# 351 :  fratelli tassis da vicenza
# 352 :  antonio tassis da vicenza
# 353 :  conte lionello lion fu del conte piero gerolemo lion gavazza
# 354 :  conte antonio valmarana
# 355 :  conte gerolemo onigo
# 356 :  giovanni gioseppe conte gioanelli
# 357 :  gaetano conte giovanelli, et fratelli
# 358 :  giuseppe conte giovanelli, et fratelli
# 359 :  giuseppe conte giovanelli
# 360 :  reverenda madre maria celeste beregan monacha a s. andrea di venetia
# 361 :  reverenda madre maria tachelli monaca a s. iseppo di venetia
# 362 :  salvador mottoni q. piero marco
# 363 :  giovanni battista grassi q. lorenzo
# 364 :  marco e agostin bernati, giustina capello, anzola foresti, iseppo bernati
# 365 :  giustina giustinian gradenigo
# 366 :  lorenzo, zaccaria, gerolamo, vicenzo e zuane balbi
# 367 :  maria falier corner e lunardo giustinian nolin
# 368 :  polo giustinian nolin
# 369 :  maria contarini surian
# 370 :  eugenio lorenzi q. lorenzo
# 371 :  agnese gradenigo r. domenico capello
# 372 :  marco contarini q. marco
# 373 :  anzolo quattri q. antonio
# 374 :  zuane dandolo q. antonio
# 375 :  piero maria contarini surian
# 376 :  lunardo dolfin de almoro
# 377 :  paolina giustinian contarini
# 378 :  alba giustinian cornaro, francesco giustinian grimani, maria giustinian contarin
# 379 :  antonia e sorella monaco
# 380 :  francesco dandolo de marco
# 381 :  giovanni battista contarini de alvise
# 382 :  francesco barbarigo de gregorio
# 383 :  simone contarini de alvise
# 384 :  anzolo michiel de marco
# 385 :  polo michiel morosin
# 386 :  francesco barbaran de camillo
# 387 :  ferigo renier de alvise
# 388 :  giacomo antonio vettor marcello fu de alvise
# 389 :  giacomo antonio vetor marcello
# 390 :  anna maria pedrini per margarita cortese
# 391 :  zuane grimani de gregorio
# 392 :  zuanne renier de costantin
# 393 :  ottavian gritti, nadal dona, alessandro e giovanni gritti zio e nipoti
# 394 :  lodovico del conte carlo quondam zambattista
# 395 :  giacomo saluzzi grizon
# 396 :  piero marin gheltof
# 397 :  illustrissimo signor conte giovanni vatieli da pesaro
# 398 :  abate don agapito burchielati da treviso
# 399 :  nobil homo conte carlo giovanelli
# 400 :  conte santonin santonini da padoa
# 401 :  nobil homo sier andrea corner fu di antonio uxorio nomine
# 402 :  chiara marcello zen come procuratrice del quondam allessandro zen cavalier
# 403 :  lugrezia porta guazzo zia de marchio e fratelli porta
# 404 :  angela benedetti, anna fabris, isabella piva bevilaqua, menegina bracchi, pietro zanchi, margarita bracchi, giovanni battista rebolfi
# 405 :  cattarina querini sua vita durante
# 406 :  zuanne e fratello conte savornian
# 407 :  zan antonio da riva
# 408 :  conte perolli
# 409 :  laura michiel bernardo
# 410 :  marc'antonio galante q. giovanni battista
# 411 :  domenico gisanelli q. antonio
# 412 :  domenico gioanelli q. antonio
# 413 :  nadal zucchini q. marco e rocco franceschetti
# 414 :  nadal zucchini q. marco
# 415 :  piero abate canal
# 416 :  isabetta grigis q. carlo
# 417 :  cattarina rota q. marco
# 418 :  antonio poli q. zuanne
# 419 :  zuanne spinardiera del q. alberto gorandi
# 420 :  conte antonio maria franzan
# 421 :  nobil homo ser lunardo dona sessonario nobil homo conte lodovico manin
# 422 :  nobil homo ser lunardo dona sessonario hobil homo conte lodovico manin
# 423 :  nobil homo lunardo dona, nobil homo conte lodovico manin
# 424 :  nobil homo lunardo dona sessonario conte lodovico manin
# 425 :  nobil homo sero giacomo miani
# 426 :  nobil homo conte giuseppe gioanelli
# 427 :  lunardo dona sessonario lodovico manin
# 428 :  giroloamo vettor marcello, francesco zen, rocco zan fermo consorti
# 429 :  alba giustinian correra
# 430 :  nobil homo ser conte sanson martinengo
# 431 :  zuanne bragadin sessonario mattio mezi
# 432 :  zuanne battista aquisti e mocenighi sesson.° carlo rosi, e gierolamo ruggia
# 433 :  nobil homo ser zuanne aquisti, e nobil homo mocenighi sess° carlo rossi murer
# 434 :  francesco zanchi sessonario alvise pavin
# 435 :  reverendi padri di s. steffano cessionari di lunardo e domenico sagredi di francesco
# 436 :  marco benzon fu de annibale per nome di marina benzon sua madre
# 437 :  giacomo soranzo de bastian procurator
# 438 :  conti polcenighi
# 439 :  polani santa fosca
# 440 :  giacomo pasetti procurator di orsola uso di mar
# 441 :  giusti antonio erizzo
# 442 :  altadonna contarini, consorte del conte bevilacqua
# 443 :  giovanni conte vatielli da pesaro
# 444 :  eredita del fu abbate giovanni donato correggio aministrata dalla fraterna de vergognosi
# 445 :  zan francesco barbarigo fu di gregorio
# 446 :  conti zenobi
# 447 :  zan battista zen fu di marco
# 448 :  angela pauli relita di francesco terzi abitante in colbertaldo
# 449 :  paulina civran fu de nicolo relita de iseppo maria polvaio
# 450 :  zuanne negri segretario
# 451 :  giacomo quondam giam maria piceni conte
# 452 :  giovanni maria raspi de ser francesco
# 453 :  signor conte giuseppe pianese
# 454 :  graziosa morosini de ser lodovico
# 455 :  conte antonio maria bonacossi da ferrara uxorio nomine
# 456 :  conte rinaldo zoppi
# 457 :  conti calliffi
# 458 :  niccolo donato de zuanne cavalier
# 459 :  conte silvestro ferri da padua
# 460 :  conte silvestro ferri
# 461 :  andriana basadona de alvise
# 462 :  vittoria basadona de ser alvise
# 463 :  conti poleni da padoa
# 464 :  conti zenobii
# 465 :  conte zenobio
# 466 :  conte bertoldo cesare vuolveson
# 467 :  giovanni battista nicolo contarin
# 468 :  michel morosini per prima genitura marc'antonio morosini
# 469 :  paulina contarina contarini
# 470 :  zan antonio dolfin
# 471 :  zan battista dolfin
# 472 :  benetto girolamo lion cavaza
# 473 :  girolamo lion cavazza
# 474 :  giulio e angelo contarini san benetto
# 475 :  giorgio zandini procurator di giacomo pava console della gran bretagna
# 476 :  elisabetta boromea marcolini da conselve meta
# 477 :  alvise magno santa ternita
# 478 :  pietro dona san bastian
# 479 :  leonardo mocengio sam samuel
# 480 :  daniel morosini, girolamo polani, alvise e fratelli damula, bernardo corner san polo
# 481 :  antonio marin bernardo
# 482 :  marco molin della maddalena
# 483 :  marc'antonio tiepolo e girolamo morosini schiavina
# 484 :  alessandro trevisan q. carlo
# 485 :  elisabetta reffai q. antonio
# 486 :  fiorenza lion marcello
# 487 :  fiorenzo lion marcello
# 488 :  conte corbelli
# 489 :  conti zanobri
# 490 :  conte zanobri
# 491 :  elena michiel zane
# 492 :  zuanne dolfin fu de vicenzo per suo uso
# 493 :  zuanne corner fu de girolamo per suo uso
# 494 :  fratelli girolamo e giacomo morosini fu de andrea per suo uso
# 495 :  zuanne foscarini fu de anzolo per suo uso
# 496 :  lorenzo dona de nadal
# 497 :  gerolemo michiel lin scuode lodovico manin
# 498 :  antonio mocenigo, antonio e nipoti giustiniani, angela buzi, angelo pivo
# 499 :  maria fausta gattelli monaca in malamocco
# 500 :  conte marc'antonio trento
# 501 :  conte piero dorizi
# 502 :  ferdinando crivelli,ferdinando lucatello,paola e maddalena brazetti,zuanne bianc
# 503 :  lorenzo, federico e francesco, fratelli e nipoti tiepolo

# %% [markdown]
# #### Distribution of all owner codes
# Except unassigned and to-verify

# %%
filtered_df = df[~df['owner_code'].str.contains('VRF') & (df['owner_code'] != 'TODO')].copy()

print(filtered_df['owner_code'].value_counts())

owner_code_counts = filtered_df['owner_code'].value_counts().reset_index()
owner_code_counts.columns = ['owner_code', 'count']

fig = px.bar(owner_code_counts, x='owner_code', y='count', title='Distribution of Owner Codes')
fig.update_layout(xaxis={'categoryorder':'total descending'})
fig.update_layout(height=600)
fig.update_traces(texttemplate='%{y}', textposition='inside')
fig.show()
# Out:
# owner_code
# PPL                          22462
# PPL_m                         4331
# ent_REL                       1636
# ent_SCL_GRD                    963
# ent_REL_TTL                    901
# ent_VNZ                        325
# ent_OTH                        290
# BLK                            279
# ent_SCR                        265
# ent_REL_TTL_UNL                179
# ent_REL_UNL                    137
# ent_SCR_m                       83
# UNK                             75
# ent_SCL_REL                     62
# ent_SCL_MST                     58
# ent_SCL_UNL                     57
# ent_GLD                         53
# ent_VNZ_TTL                     52
# ent_REL_TTL_m                   41
# ent_JEW                         30
# ent_REL_m                       30
# ent_SCL_MST_m                   10
# ent_REL_UNL_m | ent_REL_m        7
# ent_REL_TTL_UNL_m                6
# ent_SCR_UNL                      6
# ent_VNZ_UNL                      4
# ent_REL_m | PPL_m                2
# ent_SCL_UNL_m | PPL_m            2
# ent_VNZ_m                        2
# ent_VNZ_m | PPL_m | PPL_m        2
# PPL_m | ent_REL_m                2
# ent_SCR_UNL_m                    1
# ent_REL_UNL_m                    1
# PPL_m | ent_OTH_m                1
# PPL_m | ent_SCL_UNL_m            1
# ent_GLD_m | PPL_m                1
# ent_SCL_UNL_m                    1
# ent_SCL_REL_m | PPL_m            1
# ent_OTH_m                        1
# Name: count, dtype: int64

# %% [markdown]
# ## Distribution of Entities

# %%
min_occurrences = 1
num_displayed = 20

# %% [markdown]
# ### Distribution of Entity Owner Codes

# %%
entity_code_mapping = {
    'ent_GLD': 'Guild entities',
    'ent_JEW': 'Jew entities',
    'ent_OTH': 'Other entities',
    'ent_REL_UNL': 'Religious *unlinked* entities',
    'ent_REL': 'Religious entities',
    'ent_REL_TTL_UNL': 'Religious Title *unlinked* entities',
    'ent_REL_TTL': 'Religious Title entities',
    'ent_SCL_UNL': 'Scuole *unlinked* entities',
    'ent_SCL_GRD': 'Scuole Grandi entities',
    'ent_SCL_MST': 'Scuole Mestieri entities',
    'ent_SCL_REL': 'Scuole Religious entities',
    'ent_SCR_UNL': 'Social Care *unlinked* entities',
    'ent_SCR': 'Social Care entities',
    'ent_VNZ': 'Repubblica di Venezia',
    'ent_VNZ_TTL': 'Title Repubblica di Venezia',
    'ent_VNZ_UNL': '*unlinked* Repubblica di Venezia'
}

# %%
filtered_df_ent_types = df[df['owner_code'].str.startswith('ent_')].copy()

filtered_df_ent_types.loc[:, 'owner_code'] = filtered_df_ent_types['owner_code'].map(lambda x: x[:-2] if x.endswith('_m') else x)
filtered_df_ent_types.loc[:, 'owner_legend'] = filtered_df_ent_types['owner_code'].map(entity_code_mapping)

pie_fig = px.pie(filtered_df_ent_types, names='owner_legend', title='Distribution of Entity Types (Pie Chart)')
pie_fig.update_layout(height=500)
pie_fig.show()

hist_fig = px.histogram(filtered_df_ent_types, x='owner_legend', title='Distribution of Entity Types (Histogram)')
hist_fig.update_layout(height=500)
hist_fig.update_traces(texttemplate='%{y}', textposition='inside')
hist_fig.show()

# %% [markdown]
# ### Religious entities

# %% [markdown]
# #### Entities (religious)

# %% [markdown]
# ##### Entity mentions assigned to parcels (religious)

# %%
filtered_df_ent_rel = df[df['owner_code'].str.startswith('ent_REL')].copy()
filtered_df_ent_rel['owner_entity_display'] = filtered_df_ent_rel['owner_entity']

entity_counts = filtered_df_ent_rel['owner_entity_display'].value_counts()
filtered_entity_counts = entity_counts[entity_counts >= min_occurrences]

top_entities = filtered_entity_counts.head(num_displayed)

fig = px.bar(top_entities, x=top_entities.index, y=top_entities.values, 
             labels={'y': 'count', 'index': 'owner_entity_display'}, 
             title=f'Top {num_displayed} Religious entities with more than {min_occurrences} occurrences')

fig.update_layout(height=600) 
fig.update_traces(texttemplate='%{y}', textposition='inside')
fig.show()

# %% [markdown]
# ##### Stadardised entities assigned to parcels (religious)

# %%
filtered_df_ent_rel = df[df['owner_code'].str.startswith('ent_REL')].copy()
filtered_df_ent_rel['owner_entity_group_display'] = filtered_df_ent_rel['owner_entity_group']

entity_counts = filtered_df_ent_rel['owner_entity_group_display'].value_counts()
filtered_entity_counts = entity_counts[entity_counts >= min_occurrences]

top_entities = filtered_entity_counts.head(num_displayed)

fig = px.bar(top_entities, x=top_entities.index, y=top_entities.values, 
             labels={'y': 'count', 'index': 'owner_entity_group_display'}, 
             title=f'Top {num_displayed} Religious entities with more than {min_occurrences} occurrences')

fig.update_layout(height=600)
fig.update_traces(texttemplate='%{y}', textposition='inside')
fig.show()

# %% [markdown]
# #### Title-owned (Religious) parametrised on rent

# %%
# TODO

# %% [markdown]
# #### Titles (religious)

# %% [markdown]
# ##### Entities owners of the title's parcel (religious)

# %%
filtered_df_ent_rel = df[df['owner_code'].str.startswith('ent_REL_TTL')].copy()
filtered_df_ent_rel['owner_entity_group_display'] = filtered_df_ent_rel['owner_entity_group']

entity_counts = filtered_df_ent_rel['owner_entity_group_display'].value_counts()
filtered_entity_counts = entity_counts[entity_counts >= min_occurrences]

top_entities = filtered_entity_counts.head(num_displayed)

fig = px.bar(top_entities, x=top_entities.index, y=top_entities.values, 
             labels={'y': 'count', 'index': 'owner_entity_group_display'}, 
             title=f'Top {num_displayed} (Title owned) Religious entities with more than {min_occurrences} occurrences')

fig.update_layout(height=600)
fig.update_traces(texttemplate='%{y}', textposition='inside')
fig.show()

# %% [markdown]
# ##### Title mentions assigned to parcels (religious)

# %%
filtered_df_ent_rel = df[(df['owner_code'].str.len() > 0) & df['owner_code'].str.startswith('ent_REL_TTL')].copy()
filtered_df_ent_rel['owner_title'] = filtered_df_ent_rel['owner_title']

entity_counts = filtered_df_ent_rel['owner_title'].value_counts()
filtered_entity_counts = entity_counts[entity_counts >= min_occurrences]

top_entities = filtered_entity_counts.head(num_displayed)

fig = px.bar(top_entities, x=top_entities.index, y=top_entities.values, 
             labels={'y': 'count', 'index': 'owner_entity_group_display'}, 
             title=f'Top {num_displayed} Religious Title mentions with more than {min_occurrences} occurrences')

fig.update_layout(height=500)
fig.update_traces(texttemplate='%{y}', textposition='inside')
fig.show()

# %% [markdown]
# ##### Stadardised titles assigned to parcels (religious)

# %%
filtered_df_ent_rel = df[(df['owner_code'].str.len() > 0) & (df['owner_title_std'].str.len() > 0) & df['owner_code'].str.startswith('ent_REL_TTL')].copy()

entity_counts = filtered_df_ent_rel['owner_title_std'].value_counts()
filtered_entity_counts = entity_counts[entity_counts >= min_occurrences]

top_entities = filtered_entity_counts.head(num_displayed)

fig = px.bar(top_entities, x=top_entities.index, y=top_entities.values, 
             labels={'y': 'count', 'index': 'owner_entity_group_display'}, 
             title=f'Top {num_displayed} standardised Religious titles with more than {min_occurrences} occurrences')

fig.update_layout(height=500)
fig.update_traces(texttemplate='%{y}', textposition='inside')
fig.show()

# %% [markdown]
# ### Venezia entities

# %% [markdown]
# #### Entities (R. di Venezia)

# %% [markdown]
# ##### Entity mentions assigned to parcels (R. di Venezia)

# %%
filtered_df_ent_vnz = df[df['owner_code'].str.startswith('ent_VNZ')].copy()
filtered_df_ent_vnz['owner_entity_display'] = filtered_df_ent_vnz['owner_entity']

entity_counts = filtered_df_ent_vnz['owner_entity_display'].value_counts()
filtered_entity_counts = entity_counts[entity_counts >= min_occurrences]

top_entities = filtered_entity_counts.head(num_displayed)

fig = px.bar(top_entities, x=top_entities.index, y=top_entities.values, 
             labels={'y': 'count', 'index': 'owner_entity_display'}, 
             title=f'Top {num_displayed} R. di Venezia mentions with more than {min_occurrences} occurrences')

fig.update_layout(height=650)
fig.update_traces(texttemplate='%{y}', textposition='inside')
 

fig.show()

# %% [markdown]
# ##### Stadardised entities assigned to parcels (R. di Venezia)

# %%
filtered_df_ent_vnz = df[df['owner_code'].str.startswith('ent_VNZ')].copy()
filtered_df_ent_vnz['owner_entity_group_display'] = filtered_df_ent_vnz['owner_entity_group']

entity_counts = filtered_df_ent_vnz['owner_entity_group_display'].value_counts()
filtered_entity_counts = entity_counts[entity_counts >= min_occurrences]

top_entities = filtered_entity_counts.head(num_displayed)

fig = px.bar(top_entities, x=top_entities.index, y=top_entities.values, 
             labels={'y': 'count', 'index': 'owner_entity_group_display'}, 
             title=f'Top {num_displayed} R. di Venezia entities with more than {min_occurrences} occurrences')

fig.update_traces(texttemplate='%{y}', textposition='inside')
fig.update_layout(height=650)
fig.show()

# %% [markdown]
# #### Titles (R. di Venezia)

# %% [markdown]
# ##### Entities owners of the title's parcel (R. di Venezia)

# %%
filtered_df_ent_vnz = df[df['owner_code'].str.startswith('ent_VNZ_TTL')].copy()
filtered_df_ent_vnz['owner_entity_group_display'] = filtered_df_ent_vnz['owner_entity_group']

entity_counts = filtered_df_ent_vnz['owner_entity_group_display'].value_counts()
filtered_entity_counts = entity_counts[entity_counts >= min_occurrences]

top_entities = filtered_entity_counts.head(num_displayed)

fig = px.bar(top_entities, x=top_entities.index, y=top_entities.values, 
             labels={'y': 'count', 'index': 'owner_entity_group_display'}, 
             title=f'Top {num_displayed} (Title owned) R. di Venezia entities with more than {min_occurrences} occurrences')

fig.update_layout(height=600)
fig.update_traces(texttemplate='%{y}', textposition='inside')
fig.show()

# %% [markdown]
# ##### Title mentions assigned to parcels (R. di Venezia)

# %%
filtered_df_ent_vnz = df[(df['owner_code'].str.len() > 0) & df['owner_code'].str.startswith('ent_VNZ_TTL')].copy()
filtered_df_ent_vnz['owner_title'] = filtered_df_ent_vnz['owner_title']

entity_counts = filtered_df_ent_vnz['owner_title'].value_counts()
filtered_entity_counts = entity_counts[entity_counts >= min_occurrences]

top_entities = filtered_entity_counts.head(num_displayed)

fig = px.bar(top_entities, x=top_entities.index, y=top_entities.values, 
             labels={'y': 'count', 'index': 'owner_entity_group_display'}, 
             title=f'Top {num_displayed} R. di Venezia Title mentions with more than {min_occurrences} occurrences')

fig.update_layout(height=600)
fig.update_traces(texttemplate='%{y}', textposition='inside')
fig.show()

# %% [markdown]
# ##### Stadardised titles assigned to parcels (R. di Venezia)

# %%
filtered_df_ent_vnz = df[(df['owner_code'].str.len() > 0) & df['owner_code'].str.startswith('ent_VNZ_TTL')].copy()

entity_counts = filtered_df_ent_vnz['owner_title_std'].value_counts()
filtered_entity_counts = entity_counts[entity_counts >= min_occurrences]

top_entities = filtered_entity_counts.head(num_displayed)

fig = px.bar(top_entities, x=top_entities.index, y=top_entities.values, 
             labels={'y': 'count', 'index': 'owner_entity_group_display'}, 
             title=f'Top {num_displayed} standardised R. di Venezia titles with more than {min_occurrences} occurrences')

fig.update_layout(height=500)
fig.update_traces(texttemplate='%{y}', textposition='inside')
fig.show()

# %% [markdown]
# ### Scuole entities

# %% [markdown]
# #### Distribution of Scuole types

# %%
scuole_df = df[df['owner_code'].str.contains('ent_SCL_')].copy()
scuole_df['Scuole Type'] = scuole_df['owner_code'].map(entity_code_mapping)

scuole_counts = scuole_df['Scuole Type'].value_counts().reset_index()
scuole_counts.columns = ['Scuole Type', 'count']

fig = px.pie(scuole_counts, names='Scuole Type', values='count', 
             title='Count of Different Types of Scuole')
fig.update_layout(height=500)
fig.show()

# %% [markdown]
# #### Scuole Grandi

# %%
scuole_df = df[df['owner_code'].str.startswith('ent_SCL_GRD')].copy()
scuole_df['owner_entity_group_display'] = scuole_df['owner_entity_group']

entity_counts = scuole_df['owner_entity_group_display'].value_counts()
filtered_entity_counts = entity_counts[entity_counts >= min_occurrences]

top_entities = filtered_entity_counts.head(num_displayed)

fig = px.bar(top_entities, x=top_entities.index, y=top_entities.values, 
             labels={'y': 'count', 'index': 'owner_entity_group_display'}, 
             title=f'Top {num_displayed} Scuole Grandi with more than {min_occurrences} occurrences')

fig.update_layout(height=600)
fig.update_traces(texttemplate='%{y}', textposition='inside')
fig.show()

# %% [markdown]
# #### Scuole Religious

# %%
scuole_df = df[df['owner_code'].str.startswith('ent_SCL_REL')].copy()
scuole_df['owner_entity_group_display'] = scuole_df['owner_entity_group']

entity_counts = scuole_df['owner_entity_group_display'].value_counts()
filtered_entity_counts = entity_counts[entity_counts >= min_occurrences]

top_entities = filtered_entity_counts.head(num_displayed)

fig = px.bar(top_entities, x=top_entities.index, y=top_entities.values, 
             labels={'y': 'count', 'index': 'owner_entity_group_display'}, 
             title=f'Top {num_displayed} Scuole Religious with more than {min_occurrences} occurrences')

fig.update_layout(height=600)
fig.update_traces(texttemplate='%{y}', textposition='inside')
fig.show()

# %% [markdown]
# #### Scuole Mestieri

# %%
scuole_df = df[df['owner_code'].str.startswith('ent_SCL_MST')].copy()
scuole_df['owner_entity_group_display'] = scuole_df['owner_entity_group']

entity_counts = scuole_df['owner_entity_group_display'].value_counts()
filtered_entity_counts = entity_counts[entity_counts >= min_occurrences]

top_entities = filtered_entity_counts.head(num_displayed)

fig = px.bar(top_entities, x=top_entities.index, y=top_entities.values, 
             labels={'y': 'count', 'index': 'owner_entity_group_display'}, 
             title=f'Top {num_displayed} Scuole Mestieri with more than {min_occurrences} occurrences')

fig.update_layout(height=500)
fig.update_traces(texttemplate='%{y}', textposition='inside')
fig.show()

# %% [markdown]
# ### Social Care and Guild Entities

# %% [markdown]
# #### Social Care

# %%
social_care_df = df[df['owner_code'].str.startswith('ent_SCR')].copy()
social_care_df['owner_entity_group_display'] = social_care_df['owner_entity_group']

entity_counts = social_care_df['owner_entity_group_display'].value_counts()
filtered_entity_counts = entity_counts[entity_counts >= min_occurrences]

top_entities = filtered_entity_counts.head(num_displayed)


fig = px.bar(top_entities, x=top_entities.index, y=top_entities.values, 
             labels={'y': 'count', 'index': 'owner_entity_group_display'}, 
             title=f'Top {num_displayed} Social Care entities with more than {min_occurrences} occurrences')

fig.update_layout(height=600)
fig.update_traces(texttemplate='%{y}', textposition='inside')
fig.show()

# %% [markdown]
# #### Guild

# %%
guild_df = df[df['owner_code'].str.startswith('ent_GLD')].copy()
guild_df['owner_entity_group_display'] = guild_df['owner_entity_group']

entity_counts = guild_df['owner_entity_group_display'].value_counts()
filtered_entity_counts = entity_counts[entity_counts >= min_occurrences]

top_entities = filtered_entity_counts.head(num_displayed)

fig = px.bar(top_entities, x=top_entities.index, y=top_entities.values, 
             labels={'y': 'count', 'index': 'owner_entity_group_display'}, 
             title=f'Top {num_displayed} Guild entities with more than {min_occurrences} occurrences')

fig.update_layout(height=500)
fig.update_traces(texttemplate='%{y}', textposition='inside')
fig.show()

# %% [markdown]
# #### Jew entities

# %%
jew_df = df[df['owner_code'].str.startswith('ent_JEW')].copy()
jew_df['owner_entity_group_display'] = jew_df['owner_entity_group']

entity_counts = jew_df['owner_entity_group_display'].value_counts()
filtered_entity_counts = entity_counts[entity_counts >= min_occurrences]

top_entities = filtered_entity_counts.head(num_displayed)

fig = px.bar(top_entities, x=top_entities.index, y=top_entities.values, 
             labels={'y': 'count', 'index': 'owner_entity_group_display'}, 
             title=f'Top {num_displayed} Jew entities with more than {min_occurrences} occurrences')

fig.update_layout(height=500)
fig.update_traces(texttemplate='%{y}', textposition='inside')
fig.show()

# %% [markdown]
# ### Misclassifications: Entities
#
# According to most common mention (not to Entity group name).

# %% [markdown]
# #### Number of misclassifications in non-grouped mentions (pre-standardisation)

# %%
misclassification_entities_df = df[(df['owner_entity'].str.len() > 0) | (df['owner_entity_group'].str.len() > 0)].copy()

most_common_names = misclassification_entities_df.groupby('owner_entity_group')['owner_entity'].agg(
    lambda x: x.mode()[0] if not x.mode().empty else pd.NA
).reset_index().rename(columns={'owner_entity': 'most_common_name'})
misclassification_entities_df = misclassification_entities_df.merge(most_common_names, on='owner_entity_group')

misclassification_entities_df['misclassified'] = misclassification_entities_df['owner_entity'] != misclassification_entities_df['most_common_name']

group_summary = misclassification_entities_df.groupby('owner_entity_group').agg(
    total_ownerships=('owner_entity_group', 'size'),  # total occurrences of each entity group
    misclassified=('misclassified', 'sum')  # sum of misclassified instances per group
).reset_index()

group_summary['misclassification_percentage'] = (group_summary['misclassified'] / group_summary['total_ownerships']) * 100
group_summary['misclassification_percentage'] = group_summary['misclassification_percentage'].round(2)

# %%
group_summary_sorted_misclassified_ent = group_summary.sort_values(by='misclassified', ascending=False)

fig1 = px.bar(group_summary_sorted_misclassified_ent.head(num_displayed), x='owner_entity_group', y='misclassified',
              text='misclassified',
              labels={'misclassified': 'Number of Misclassifications', 'owner_entity_group': 'Entity Group'},
              title=f'Top {num_displayed} Entity Groups with higher number of Misclassifications')
fig1.update_traces(texttemplate='%{text}', textposition='outside')
fig1.update_layout(xaxis={'categoryorder': 'total descending'}, yaxis_title="Number of Misclassifications")


group_summary_sorted_occurrences_ent = group_summary.sort_values(by='total_ownerships', ascending=False)

fig2 = px.bar(group_summary_sorted_occurrences_ent.head(num_displayed), x='owner_entity_group', y='misclassified',
              text='misclassified',
              labels={'misclassified': 'Number of Misclassifications', 'owner_entity_group': 'Entity Group', 'total_ownerships': 'Total Ownerships'},
              title=f'Number of Misclassifications of Top {num_displayed} Entity Groups by Number of Ownerships')
fig2.update_traces(texttemplate='%{text}', textposition='outside')

fig1.update_traces(texttemplate='%{y}', textposition='inside')
fig2.update_traces(texttemplate='%{y}', textposition='inside')
fig1.update_layout(height=650)
fig2.update_layout(height=650)
fig1.show()
fig2.show()

# %% [markdown]
# #### Percentage (%) of misclassifications in non-grouped mentions (pre-standardisation)

# %%
group_summary_sorted_percentage_ent = group_summary.sort_values(by='misclassification_percentage', ascending=False)
group_summary_sorted_percentage_ent['misclassification_percentage'] = group_summary_sorted_percentage_ent['misclassification_percentage'].round(2)

fig1 = px.bar(group_summary_sorted_percentage_ent.head(num_displayed), x='owner_entity_group', y='misclassification_percentage',
              text='misclassification_percentage',
              labels={'misclassification_percentage': 'Misclassification Percentage (%)', 'owner_entity_group': 'Entity Group'},
              title=f'Top {num_displayed} Entity Groups with higher percentage of misclassification')
fig1.update_traces(texttemplate='%{text:.2f}%', textposition='outside')
fig1.update_layout(xaxis={'categoryorder': 'total descending'}, yaxis_title="Misclassification Percentage", yaxis_tickformat='.2f')

group_summary_sorted_occurrences_ent = group_summary.sort_values(by='total_ownerships', ascending=False)
group_summary_sorted_occurrences_ent['text'] = group_summary_sorted_occurrences_ent.apply(lambda row: f"{row['misclassified']} / {row['total_ownerships']}", axis=1)

group_summary_sorted_occurrences_ent['display_text'] = group_summary_sorted_occurrences_ent.apply(
    lambda row: f"{row['misclassified']} di {row['total_ownerships']}", axis=1)

fig1 = px.bar(group_summary_sorted_occurrences_ent.head(num_displayed), x='owner_entity_group', y='misclassification_percentage',
              text='display_text',  
              labels={'misclassification_percentage': 'Misclassification Percentage (%)', 'owner_entity_group': 'Entity Group'},
              title=f'Top {num_displayed} Entity Groups with higher percentage of misclassification')
fig1.update_traces(texttemplate='%{text}', textposition='outside')  
fig1.update_layout(xaxis={'categoryorder': 'total descending'}, yaxis_title="Misclassification Percentage", yaxis_tickformat='.2f')


fig2 = px.bar(group_summary_sorted_occurrences_ent.head(num_displayed), x='owner_entity_group', y='misclassification_percentage',
              text='display_text',  
              labels={'misclassification_percentage': 'Misclassification Percentage (%)', 'owner_entity_group': 'Entity Group', 'total_ownerships': 'Total Ownerships'},
              title=f'Percentage of misclassification of top {num_displayed} Entity Groups by number ownerships')
fig2.update_traces(texttemplate='%{text}', textposition='outside')

fig1.update_traces(texttemplate='%{y}', textposition='inside')
fig2.update_traces(texttemplate='%{y}', textposition='inside')
fig1.update_layout(height=650)
fig2.update_layout(height=650)
fig1.show()
fig2.show()

# %% [markdown]
# #### Total misclassifications (Entities)

# %%
misclassified_df = misclassification_entities_df[misclassification_entities_df['owner_code'].str.startswith('ent')].copy()
misclassified_df['classification_status'] = misclassified_df['misclassified'].map({True: 'Misclassified', False: 'Correct'})

classification_counts = misclassified_df['classification_status'].value_counts()

fig = px.pie(values=classification_counts.values, 
             names=classification_counts.index, 
             title='Entities: Percentage of Misclassifications')

fig.update_traces(textinfo='percent+label')
fig.update_layout(height=400)
fig.show()

# %% [markdown]
# ## Distribution of Families

# %% [markdown]
# #### Load Catastici 1741 expanded version
#
# The expanded version was obtained by creating one row for every owner. If a parcel is owned by $n$ owners, $n$ rows have been created with the same parcel uidx prefix. For example, if parcel 123 is owned by two people, rows with uidx 123_0 and 123_1 are created with the information of the respective owners. Furthermore, a new column `parcel_portion` has been cerated. This attribute is a number from 0 to 1 representing the portion of the parcel owned by this owner. In case of parcel 123 owned by two people this value is 0.5 for each owner.

# %%
df_families = pd.read_json('../data_catastici/data_post-processing/pipeline_steps/catastici_1741_STD_expanded.json', dtype={'uidx': str})

# %%
min_occurrences = 1
num_displayed = 20

# %%
owner_code_mapping = {
    'PPL': 'Person',
    'PPL_m': 'Person (model output)',
    'PPL_VRF': 'Person (to verify)'
}

# %% [markdown]
# ### Distribution of People Owner Codes

# %%
df_families['owner_category'] = df_families['owner_code'].map(lambda x: owner_code_mapping.get(x, 'Person (other)') if 'PPL' in x else 'Non-Person').copy()
df_families = df_families[df_families['owner_code'].str.contains('PPL')]

category_counts = df_families['owner_category'].value_counts().reset_index()
category_counts.columns = ['owner_category', 'count']

pie_fig = px.pie(category_counts, names='owner_category', values='count', 
                 title='Distribution of Owner Codes for People')
pie_fig.update_layout(height=400)
pie_fig.show()

# %% [markdown]
# ### Distribution of Family ownership

# %% [markdown]
# #### Distribution of Family mentions

# %%
family_counts_df = df_families.groupby('owner_family_name')['parcel_portion'].sum().reset_index().rename(columns={'parcel_portion': 'weighted_count'})
family_counts_df = family_counts_df.sort_values(by='weighted_count', ascending=False)

filtered_family_counts = family_counts_df[family_counts_df['weighted_count'] >= min_occurrences]
top_families = filtered_family_counts.head(num_displayed)
top_families = top_families[top_families['owner_family_name'] != '']

hist_fig = px.bar(top_families, x='owner_family_name', y='weighted_count',
                  labels={'weighted_count': 'Weighted Number of Occurrences', 'owner_family_name': 'Family Group'}, 
                  title=f'Distribution of Family Ownership - Weighted by Ownership Portion')

hist_fig.update_layout(height=500)
hist_fig.update_traces(texttemplate='%{y}', textposition='inside')
hist_fig.show()

# %% [markdown]
# #### Distribution of standardised Family Groups

# %%
family_counts_df = df_families.groupby('owner_family_group')['parcel_portion'].sum().reset_index().rename(columns={'parcel_portion': 'weighted_count'})
family_counts_df = family_counts_df.sort_values(by='weighted_count', ascending=False)

filtered_family_counts = family_counts_df[family_counts_df['weighted_count'] >= min_occurrences]
top_families = filtered_family_counts.head(num_displayed)
top_families = top_families[top_families['owner_family_group'] != '']

hist_fig = px.bar(top_families, x='owner_family_group', y='weighted_count',
                  labels={'weighted_count': 'Weighted Number of Occurrences', 'owner_family_group': 'Family Group'}, 
                  title=f'Distribution of Family Ownership - Weighted by Ownership Portion')

hist_fig.update_layout(height=500)
hist_fig.update_traces(texttemplate='%{y}', textposition='inside')
hist_fig.show()

# %% [markdown]
# ### Misclassifications: Families

# %% [markdown]
# #### Number of misclassifications in non-grouped mentions (pre-standardisation)
#
# According to most common mention (not to Family group name).

# %%
most_common_names = df_families.groupby('owner_family_group')['owner_family_name'].agg(
    lambda x: x.mode()[0] if not x.mode().empty else pd.NA
).reset_index().rename(columns={'owner_family_name': 'most_common_name'})
df_families = df_families.merge(most_common_names, on='owner_family_group')

df_families['misclassified'] = df_families['owner_family_name'] != df_families['most_common_name']

group_summary_families = df_families.groupby('owner_family_group').agg(
    total_ownerships=('owner_family_group', 'size'),  # total occurrences of each family group
    misclassified=('misclassified', 'sum')  # sum of misclassified instances per group
).reset_index()

group_summary_families['misclassification_percentage'] = (group_summary_families['misclassified'] / group_summary_families['total_ownerships']) * 100
group_summary_families['misclassification_percentage'] = group_summary_families['misclassification_percentage'].round(2)

# %%
group_summary_families_misclassified = group_summary_families.sort_values(by='misclassified', ascending=False)

fig1 = px.bar(group_summary_families_misclassified.head(num_displayed), x='owner_family_group', y='misclassified',
              text='misclassified',
              labels={'misclassified': 'Number of Misclassifications', 'owner_family_group': 'Family Group'},
              title=f'Top {num_displayed} Family Groups with higher number of Misclassifications')
fig1.update_traces(texttemplate='%{text}', textposition='outside')
fig1.update_layout(xaxis={'categoryorder': 'total descending'}, yaxis_title="Number of Misclassifications")


group_summary_families_sorted_occurrences = group_summary_families.sort_values(by='total_ownerships', ascending=False)

fig2 = px.bar(group_summary_families_sorted_occurrences.head(num_displayed), x='owner_family_group', y='misclassified',
              text='misclassified',
              labels={'misclassified': 'Number of Misclassifications', 'owner_family_group': 'Family Group', 'total_ownerships': 'Total Ownerships'},
              title=f'Number of Misclassifications of Top {num_displayed} Family Groups by Number of Ownerships')
fig2.update_traces(texttemplate='%{text}', textposition='outside')

fig1.update_layout(height=500)
fig2.update_layout(height=500)
fig1.update_traces(texttemplate='%{y}', textposition='inside')
fig2.update_traces(texttemplate='%{y}', textposition='inside')
fig1.show()
fig2.show()

# %% [markdown]
# #### Percentage (%) of misclassifications in non-grouped mentions (pre-standardisation)

# %%
group_summary_families_sorted_percentage = group_summary_families.sort_values(by='misclassification_percentage', ascending=False)
group_summary_families_sorted_percentage['misclassification_percentage'] = group_summary_families_sorted_percentage['misclassification_percentage'].round(2)

fig1 = px.bar(group_summary_families_sorted_percentage.head(num_displayed), x='owner_family_group', y='misclassification_percentage',
              text='misclassification_percentage',
              labels={'misclassification_percentage': 'Misclassification Percentage (%)', 'owner_family_group': 'family Group'},
              title=f'Top {num_displayed} Family Groups with higher percentage of misclassification')
fig1.update_traces(texttemplate='%{text:.2f}%', textposition='outside')
fig1.update_layout(xaxis={'categoryorder': 'total descending'}, yaxis_title="Misclassification Percentage", yaxis_tickformat='.2f')

group_summary_families_sorted_occurrences = group_summary_families.sort_values(by='total_ownerships', ascending=False)
group_summary_families_sorted_occurrences['text'] = group_summary_families_sorted_occurrences.apply(lambda row: f"{row['misclassified']} / {row['total_ownerships']}", axis=1)

group_summary_families_sorted_occurrences['display_text'] = group_summary_families_sorted_occurrences.apply(
    lambda row: f"{row['misclassified']} di {row['total_ownerships']}", axis=1)

fig1 = px.bar(group_summary_families_sorted_occurrences.head(num_displayed), x='owner_family_group', y='misclassification_percentage',
              text='display_text',  
              labels={'misclassification_percentage': 'Misclassification Percentage (%)', 'owner_family_group': 'family Group'},
              title=f'Top {num_displayed} Family Groups with higher percentage of misclassification')
fig1.update_traces(texttemplate='%{text}', textposition='outside')  
fig1.update_layout(xaxis={'categoryorder': 'total descending'}, yaxis_title="Misclassification Percentage", yaxis_tickformat='.2f')


fig2 = px.bar(group_summary_families_sorted_occurrences.head(num_displayed), x='owner_family_group', y='misclassification_percentage',
              text='display_text',  
              labels={'misclassification_percentage': 'Misclassification Percentage (%)', 'owner_family_group': 'family Group', 'total_ownerships': 'Total Ownerships'},
              title=f'Percentage of misclassification of top {num_displayed} Family Groups by number ownerships')
fig2.update_traces(texttemplate='%{text}', textposition='outside')

fig1.update_traces(texttemplate='%{y}', textposition='inside')
fig2.update_traces(texttemplate='%{y}', textposition='inside')
fig1.update_layout(height=500)
fig2.update_layout(height=500)
fig1.show()
fig2.show()

# %% [markdown]
# #### Total misclassifications (Families)

# %%
df_families['classification_status'] = df_families['misclassified'].map({True: 'Misclassified', False: 'Correct'})
classification_counts = df_families['classification_status'].value_counts()

fig = px.pie(values=classification_counts.values, 
             names=classification_counts.index, 
             title='Families: Percentage of Misclassifications')

fig.update_traces(textinfo='percent+label')
fig.update_layout(height=400)
fig.show()

# %% [markdown]
# ### Inter-family parcel sharing

# %% [markdown]
# #### Couples of family groups sharing most parcels

# %%
from itertools import combinations
from collections import Counter
import pandas as pd
import plotly.express as px

df_families['parcel_id'] = df_families['uidx'].apply(lambda x: x.split('_')[0])

shared_parcels = df_families.groupby('parcel_id')['owner_family_group'].apply(list).reset_index()
shared_parcels = shared_parcels[shared_parcels['owner_family_group'].apply(len) > 1]

def create_couples(owner_list):
    return [' - '.join(sorted(couple)) for couple in combinations(owner_list, 2) if couple[0] != couple[1] and couple[0] != '-' and couple[1] != '-']

shared_parcels['couples'] = shared_parcels['owner_family_group'].apply(create_couples)

all_couples = Counter([couple for sublist in shared_parcels['couples'] for couple in sublist])

couples_df = pd.DataFrame(all_couples.items(), columns=['couple', 'shared_parcels'])
sorted_couples_df = couples_df.sort_values(by='shared_parcels', ascending=False)

fig = px.bar(sorted_couples_df.head(num_displayed), x='couple', y='shared_parcels',
             title=f'Top {num_displayed} Family Group Pairs by Shared Parcels',
             labels={'shared_parcels': 'Number of Shared Parcels', 'couple': 'Family Group Pair'})
fig.show()

# %% [markdown]
# #### Individual Families with most shared parcels

# %%
from collections import Counter

def count_individual_families(shared_parcels):
    individual_families = []
    
    for owner_list in shared_parcels['owner_family_group']:
        for couple in combinations(owner_list, 2):
            if couple[0] != couple[1] and couple[0] != '-' and couple[1] != '-':
                individual_families.extend(couple)
                
    return Counter(individual_families)

family_counts = count_individual_families(shared_parcels)

families_df = pd.DataFrame(family_counts.items(), columns=['Family', 'Count'])
sorted_families_df = families_df.sort_values(by='Count', ascending=False)

fig = px.bar(sorted_families_df.head(num_displayed), x='Family', y='Count',
             title='Top Individual Families with Most Shared Parcels',
             labels={'Count': 'Number of Shared Parcels', 'Family': 'Family'})
fig.show()

# %% [markdown]
# ### People's Titles and Mestieri

# %% [markdown]
# #### Titles

# %%
# TODO

# %% [markdown]
# #### Mestieri

# %%
# TODO
